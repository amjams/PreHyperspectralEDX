# %% [markdown]
# # Alignment of HAADF images with SOFIMA
# - This follows the demo here: https://colab.research.google.com/github/google-research/sofima/blob/main/notebooks/em_alignment.ipynb#scrollTo=wLapfgxDx1Sz

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from utils import *
import numpy as np
import hyperspy.api as hs
import matplotlib.pyplot as plt
import copy
from importlib import reload
from EDX import *
from skimage import data, img_as_float
from skimage import feature
import tensorstore as ts
from scipy.stats import pearsonr
from datetime import datetime
import warnings

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load all haadf images to inspect drift

# %%
# load data
file_path = "../data/EMD/EDXdataset.emd"

# load and preprocess
edx, haadf, xray_energies = load_EDX(file_path, first_frame=0, last_frame=20, sum_frames=True, haadf_last_frame=False)
#tile = EM_EDX(haadf, edx, xray_energies)
#tile.apply("crop", parameters={"crop_idx": (slice(None), slice(None), slice(96, 4096))})
#tile.apply("binning", parameters={"dim": (1024, 1024, 250)})
#tile.apply("MeanFilterEDX", parameters={"kernel_size": 3})

print(haadf.shape)
print(haadf.max())
# Out:
# WARNING | RosettaSciIO | The file contains only one spectrum stream (rsciio.emd._emd_velox:590)
# (100, 2048, 2048)
# 65535.0

# %% [markdown]
# ### Plot thresholded HAADF images from different frames to check overlap
# - The overlap is extreme between frames 0 and 1.

# %%
# colorblind colors
colors_cb = {
    "red":    {"hex": "#D55E00", "rgb": (213, 94, 0)},
    "green":  {"hex": "#009E73", "rgb": (0, 158, 115)},
    "yellow": {"hex": "#F0E442", "rgb": (240, 228, 66)},
}

# threshold
haadf_th = MinMax(haadf)>0.5

# plot range
y1, y2, x1, x2 = [750, 1250, 250, 750] 

# which frames 
tmp1, tmp2 = [0, 1]

# binarized images
img1b = haadf_th[tmp1,750:1250,250:750]
img2b = haadf_th[tmp2,750:1250,250:750]
img3b = img1b.astype('uint8') + img2b.astype('uint8')

# img dims
h, w = img1b.shape

# make appropraite images
img1 = np.zeros((h, w, 3), np.uint8)
img2 = np.zeros((h, w, 3), np.uint8)
img3 = np.zeros((h, w, 3), np.uint8)


img1[np.where(img1b)[0],np.where(img1b)[1],:] = colors_cb['red']['rgb']
img2[np.where(img2b)[0],np.where(img2b)[1],:] = colors_cb['green']['rgb']

# overlap image
img3[np.where(img1b)[0],np.where(img1b)[1],:] = colors_cb['red']['rgb']
img3[np.where(img2b)[0],np.where(img2b)[1],:] = colors_cb['green']['rgb']
img3[np.where(img3b==2)[0],np.where(img3b==2)[1],:] = colors_cb['yellow']['rgb']


# plot
f, ax = plt.subplots(1,3,figsize=(15,10))
ax[0].imshow(img1)
ax[0].set_title('Thresholded HAADF (frame %02d)' % tmp1)
ax[1].imshow(img2)
ax[1].set_title('Thresholded HAADF (frame %02d)' % tmp2)
ax[2].imshow(img3)
ax[2].set_title('Thresholded HAADF overlap (frame %02d and %02d)' % (tmp1,tmp2))



#ax[1].imshow(feature.canny(haadf_th[0,750:1250,250:750],sigma=0.8),cmap='gray')
#ax[0].title('Thresholded HAADF')
# Out:
# Text(0.5, 1.0, 'Thresholded HAADF overlap (frame 00 and 01)')

# %% [markdown]
# ## SOFIMA
# - !pip install git+https://github.com/google-research/sofima
# - demo: https://colab.research.google.com/github/google-research/sofima/blob/main/notebooks/em_alignment.ipynb#scrollTo=AZvmtg0TTBAJ
# - The demo aligns a volume. Here we treat the stack of HAADFs as a volume of sorts.

# %%
# number of channels to align
n_channels = 20


# Reorder to (2048, 2048, 100)- and limit to 20 frames
data_1x = haadf.transpose(1, 2, 0)[..., None]
data_1x = data_1x[:,:,:n_channels,:]


# create a binned version (also to match the unaligned_2x in the demo) 
data_2x = np.zeros((1024,1024,n_channels,1)) 

for i in range(data_2x.shape[2]):
    data_2x[:,:,i,0] = binning_xy(data_1x[:,:,i,:].squeeze())


# convert both sets of images to 0-255, channel wise
for i in range(data_2x.shape[2]):
    data_1x[:,:,i,0] = Normalize_uint8(data_1x[:,:,i,0]) #,normalize_by=data_1x[:,:,:,0]) #you can normalize by the whole stack
    data_2x[:,:,i,0] = Normalize_uint8(data_2x[:,:,i,0]) #,normalize_by=data_2x[:,:,i,0])
data_1x = data_1x.astype('uint8')
data_2x = data_2x.astype('uint8')


# Create the TensorStore objects for the stacks of images.
unaligned_1x = ts.open({
    'driver': 'n5',
    'kvstore': {
         'driver': 'file',
         'path': 'tmp/dataset1/',
     },
     'metadata': {
         'compression': {
             'type': 'gzip'
         },
         'dataType': 'uint8',
         'dimensions': data_1x.shape,
         'blockSize': [100, 100, 1, 1],
     },
     'create': True,
     'delete_existing': True,}).result()

unaligned_2x = ts.open({
    'driver': 'n5',
    'kvstore': {
         'driver': 'file',
         'path': 'tmp/dataset2/',
     },
     'metadata': {
         'compression': {
             'type': 'gzip'
         },
         'dataType': 'uint8',
         'dimensions': data_2x.shape,
         'blockSize': [50, 50, 1, 1],
     },
     'create': True,
     'delete_existing': True,}).result()

write_future = unaligned_1x.write(data_1x)
write_future.result()
write_future = unaligned_2x.write(data_2x)
write_future.result()

# %% [markdown]
# #### Check if things were stores correctly

# %%
f, ax = plt.subplots(1,3)
tmp_c = 15
ax[0].imshow(haadf[tmp_c,:,:],cmap='gray_r')
ax[1].imshow(unaligned_1x[:,:,tmp_c,0],cmap='gray_r')
ax[2].imshow(unaligned_2x[:,:,tmp_c,0],cmap='gray_r')
plt.show()

# %% [markdown]
# #### Check dims and stats just in case

# %%
print('Full-res set stats:')
print("Shape: ", unaligned_1x.shape)
print("Min, max, mean: ",unaligned_1x[:,:,:,:].read().result().min(),unaligned_1x[:,:,:,:].read().result().max(),unaligned_1x[:,:,:,:].read().result().mean())
print(unaligned_1x[:,:,:,:].read().result().dtype)

print('Reduced-res set stats:')
print(unaligned_2x.shape)
print("Min, max, mean: ",unaligned_2x[:,:,:,:].read().result().min(),unaligned_2x[:,:,:,:].read().result().max(),unaligned_2x[:,:,:,:].read().result().mean())
print(unaligned_2x[:,:,:,:].read().result().dtype)
# Out:
# Full-res set stats:
# Shape:  (2048, 2048, 20, 1)
# Min, max, mean:  0 255 82.87482777833938
# uint8
# Reduced-res set stats:
# (1024, 1024, 20, 1)
# Min, max, mean:  0 255 83.78087391853333
# uint8

# %% [markdown]
# #### sofima imports

# %%
import os
os.environ["JAX_PLATFORM_NAME"] = "cpu"  # change this to your convenience
import jax
print(jax.default_backend()) 

import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt

from connectomics.common import bounding_box
from sofima import flow_field
from sofima import flow_utils
from sofima import map_utils
from sofima import mesh
from sofima import warp
from tqdm.notebook import tqdm
from concurrent import futures
import time
# Out:
# WARNING:2025-11-20 19:50:15,486:jax._src.xla_bridge:879: Platform 'METAL' is experimental and not all JAX functionality may be correctly supported!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1763664615.487245 1029003 mps_client.cc:510] WARNING: JAX Apple GPU support is experimental and not all JAX functionality is correctly supported!
# I0000 00:00:1763664615.511454 1029003 service.cc:145] XLA service 0x600003c30d00 initialized for platform METAL (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763664615.511465 1029003 service.cc:153]   StreamExecutor device (0): Metal, <undefined>
# I0000 00:00:1763664615.512652 1029003 mps_client.cc:406] Using Simple allocator.
# I0000 00:00:1763664615.512660 1029003 mps_client.cc:384] XLA backend will use up to 77309018112 bytes on device 0 for SimpleAllocator.
# Metal device set to: Apple M2 Max
# cpu

# %% [markdown]
# #### Check what jax is running on.
# - 'cpu' for now is fine.

# %%
# set to cpu
# jax.default_backend()

# %% [markdown]
# ### Flow field estimation (from demo)
#
# First, we calculate the flow fields between the current section and the directly preceding section. Flow fields can also be computed between pairs of sections that are not directly adjacent. This is useful if sections are incomplete or missing, but is not something we have to worry about in this demo.
#
# #### My notes:
# - `patch_size` 4 times `stride` seems reasonable, following the demo.

# %%
# Both of the settings below are expressed in pixels.
patch_size = 100  # XY spatial context used for flow field estimation
stride = 25  # XY distance between centers of adjacent patches.

def _compute_flow(volume):
  mfc = flow_field.JAXMaskedXCorrWithStatsCalculator()
  flows = []
  prev = volume[..., 0, 0].T.read().result()

  fs = []
  with futures.ThreadPoolExecutor() as tpe:
    # Prefetch the next sections to memory so that we don't have to wait for them
    # to load when the GPU becomes available.
    for z in range(1, unaligned_1x.shape[2]):
      fs.append(tpe.submit(lambda z=z: volume[..., z, 0].T.read().result()))

    fs = fs[::-1]

    for z in tqdm(range(1, unaligned_1x.shape[2])):
      curr = fs.pop().result()

      # The batch size is a parameter which impacts the efficiency of the computation (but
      # not its result). It has to be large enough for the computation to fully utilize the
      # available GPU capacity, but small enough so that the batch fits in GPU RAM.
      flows.append(mfc.flow_field(prev, curr, (patch_size, patch_size),
                                  (stride, stride), batch_size=256))
      prev = curr

  return flows

# %% [markdown]
# #### From collab:
# Compute flows at native and 2x reduced in-plane resolution. The lower resolution flow has reduced precision, but is helpful for providing approximate flow vectors in places where the full-resolution flow might be impossible to estimate, e.g. in the interior of cell bodies or blood vessels.

# %%
flows1x_og = np.array(_compute_flow(unaligned_1x))
flows2x_og = np.array(_compute_flow(unaligned_2x))
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]

# %% [markdown]
# #### From collab:
# The flow fields generated in the previous step are 4-channel arrays, where the first two channels store the XY components of the flow vector, and the two remaining channels are measures of estimation quality (see `sofima.flow_field._batched_peaks` for more info).

# %%
# Convert to [channels, z, y, x].
flows2x = np.transpose(flows2x_og, [1, 0, 2, 3])
flows1x = np.transpose(flows1x_og, [1, 0, 2, 3])

# Pad to account for the edges of the images where there is insufficient context to estimate flow.
pad = patch_size // 2 // stride
flows1x = np.pad(flows1x, [[0, 0], [0, 0], [pad, pad], [pad, pad]], constant_values=np.nan)
flows2x = np.pad(flows2x, [[0, 0], [0, 0], [pad, pad], [pad, pad]], constant_values=np.nan)

# check dim
print(flows1x.shape,flows2x.shape)

# check nan values
print(np.isnan(flows1x).sum(),np.isnan(flows1x).sum())
print("Ratio of NaN: ", np.isnan(flows1x).sum()/flows1x.size ,np.isnan(flows2x).sum()/flows2x.size)
# Out:
# (4, 19, 82, 82) (4, 19, 41, 41)
# 48640 48640
# Ratio of NaN:  0.09518143961927424 0.18560380725758477

# %% [markdown]
# #### From collab:
# We now remove uncertain flow estimates by replacing them with NaNs, and merge the two flow arrays into a single flow field at full resolution. In a distributed environment, this step would be done with the ReconcileAndFilterFlows processor.
#
# #### My notes:
# - possible hint on hyperparameters here: https://github.com/google-research/sofima/issues/3 still no strong conclusiosn; to be tested further.
# - These seem to be critical choices.

# %%
min_peak_ratio=1.1 #1.6
min_peak_sharpness=1.1 # 1.6
max_magnitude=0 #80
max_deviation=0 #20

f1 = flow_utils.clean_flow(flows1x, min_peak_ratio=min_peak_ratio, min_peak_sharpness=min_peak_sharpness, max_magnitude=max_magnitude, max_deviation=max_deviation)
f2 = flow_utils.clean_flow(flows1x, min_peak_ratio=min_peak_ratio, min_peak_sharpness=min_peak_sharpness, max_magnitude=max_magnitude, max_deviation=max_deviation)

# check if not too many values became NaN
print("Ratio of NaN before: ", np.isnan(flows1x).sum()/flows1x.size ,np.isnan(flows2x).sum()/flows2x.size)
print("Ratio of NaN after: ", np.isnan(f1).sum()/f1.size ,np.isnan(f2).sum()/f2.size)
# Out:
# Ratio of NaN before:  0.09518143961927424 0.18560380725758477
# Ratio of NaN after:  0.09949434860202261 0.09949434860202261

# %% [markdown]
# #### From collab:
# Plot the horizontal component of the flow vector, before (left) and after (right) filtering. While blobs indicate areas where uncertain flow estimates were removed.
#
# #### Notes on below:
# - tmp1: (0, 1) horizontal and vertical flow.
# - tmp2: (n_channels-1, i.e. 19) is the flow between this channel and the one before it, so tmp2 =0 is the flow of the second haadf w.r.t the first, and tmp2 = 2 is the flow of the third w.r.t. to the second. And the flow diagrams make sense considering the observed drift in the haadfs.
# - Considering this, the logic doesn't fully align (pun-intended) with our goal. We need to match each frame with a reference (e.g. first or last frame), not with the one before it. For now, though, we keep treating it as a volume.

# %%
tmp1, tmp2 = 0, 2
f, ax = plt.subplots(2, 3, figsize=(10, 5))
ax[0][0].imshow(flows1x[tmp1, tmp2, ...], cmap=plt.cm.RdBu, vmin=-10, vmax=10)
ax[0][1].imshow(f1[tmp1, tmp2, ...], cmap=plt.cm.RdBu, vmin=-10, vmax=10)
ax[1][0].imshow(flows2x[tmp1, tmp2, ...], cmap=plt.cm.RdBu, vmin=-10, vmax=10)
ax[1][1].imshow(f2[tmp1, tmp2, ...], cmap=plt.cm.RdBu, vmin=-10, vmax=10)

# reference

# binarized images
img1b = haadf_th[tmp2+1,750:1250,250:750]
img2b = haadf_th[tmp2,750:1250,250:750]
img3b = img1b.astype('uint8') + img2b.astype('uint8')

# img dims
h, w = img1b.shape
# overlap image
img3 = np.zeros((h, w, 3), np.uint8)
img3[np.where(img1b)[0],np.where(img1b)[1],:] = colors_cb['red']['rgb']
img3[np.where(img2b)[0],np.where(img2b)[1],:] = colors_cb['green']['rgb']
img3[np.where(img3b==2)[0],np.where(img3b==2)[1],:] = colors_cb['yellow']['rgb']
ax[0][2].imshow(img3)
ax[1][2].set_axis_off()

# %%
from scipy import interpolate
f2_hires = np.zeros_like(f1)

scale = 0.5
oy, ox = np.ogrid[:f2.shape[-2], :f2.shape[-1]]
oy = oy.ravel() / scale
ox = ox.ravel() / scale

box1x = bounding_box.BoundingBox(start=(0, 0, 0), size=(f1.shape[-1], f1.shape[-2], 1))
box2x = bounding_box.BoundingBox(start=(0, 0, 0), size=(f2.shape[-1], f2.shape[-2], 1))

for z in tqdm(range(f2.shape[1])):
  # Upsample and scale spatial components.
  resampled = map_utils.resample_map(
      f2[:, z:z + 1, ...],  #
      box2x, box1x, 1 / scale, 1)
  f2_hires[:, z:z + 1, ...] = resampled / scale

final_flow = flow_utils.reconcile_flows((f1, f2_hires), max_gradient=0, max_deviation=20, min_patch_size=400)
print(final_flow.shape)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# (2, 19, 82, 82)

# %%
# Plot (left to right): high res. flow, upsampled low res. flow, combined flow to use for alignment.
tmp1, tmp2  = 1, 1
f, ax = plt.subplots(1, 3, figsize=(7.5, 2.5))
ax[0].imshow(f1[tmp1, tmp2, ...], cmap=plt.cm.RdBu,vmin=-10, vmax=10)
ax[1].imshow(f2_hires[tmp1, tmp2, ...], cmap=plt.cm.RdBu,vmin=-10, vmax=10)
ax[2].imshow(final_flow[tmp1, tmp2, ...], cmap=plt.cm.RdBu,vmin=-10, vmax=10)

# %% [markdown]
# ## Mesh optimization (from collab
#
# We use an elastic mesh optimizer to find a configuration of the imagery that is compatible with the estimated flow field and preserves the original geometry as much as possible.
#
# The optimization proceeds sequentially, section by section. In a distributed environment, this computation can be parallelized across the plane (by independently solving overlapping XY tiles), as well as split into blocks along the Z axis. This makes it possible to scale this process to arbitrarily large volumes. For simplicity, here we solve the complete stack in one go.
#
# ## Notes:
# - No change in parameters needed below (as of now).

# %%
config = mesh.IntegrationConfig(dt=0.001, gamma=0.0, k0=0.01, k=0.1, stride=(stride, stride), num_iters=1000,
                                max_iters=100000, stop_v_max=0.005, dt_max=1000, start_cap=0.01,
                                final_cap=10, prefer_orig_order=True)

# %%
solved = [np.zeros_like(final_flow[:, 0:1, ...])]
origin = jnp.array([0., 0.])

for z in tqdm(range(0, final_flow.shape[1])):
  prev = map_utils.compose_maps_fast(final_flow[:, z:z+1, ...], origin, stride,
                                     solved[-1], origin, stride)
  x = np.zeros_like(solved[0])
  x, e_kin, num_steps = mesh.relax_mesh(x, prev, config)
  x = np.array(x)
  solved.append(x)

solved = np.concatenate(solved, axis=1)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]

# %% [markdown]
# ## Image warping (from colab):
# Image warping requires an inverse coordinate map, so compute that first. In a distributed environment, this can be done with the `InvertMap` processor.

# %%
inv_map = map_utils.invert_map(solved, box1x, box1x, stride)

warped = [np.transpose(unaligned_1x[:, :, 0:1, 0].read().result(), [2, 1, 0])]

for z in tqdm(range(1, unaligned_1x.shape[2])):
  data_box = bounding_box.BoundingBox(start=(0, 0, 0), size=(2048, 2048, 1))
  out_box = bounding_box.BoundingBox(start=(0, 0, 0), size=(2048, 2048, 1))

  data = np.transpose(unaligned_1x[data_box.start[0]:data_box.end[0],
                                   data_box.start[1]:data_box.end[1],
                                   z:z+1, 0:1].read().result(), [3, 2, 1, 0])
  warped.append(
      warp.warp_subvolume(data, data_box, inv_map[:, z:z+1, ...], box1x, stride, out_box, 'lanczos', parallelism=1)[0, ...])

warped_xyz = np.transpose(np.concatenate(warped, axis=0), [2, 1, 0])
print(warped_xyz.shape)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# (2048, 2048, 20)

# %% [markdown]
# ## Padded warping (GPT-assisted)
# - Note: this crops the input image before warping

# %%
pad_remove = patch_size // 2

# Crop region size
crop_size = 2048 - 2*pad_remove

inv_map = map_utils.invert_map(solved, box1x, box1x, stride)

# Initialize warped list with cropped slice 0
warped = [np.transpose(unaligned_1x[pad_remove:2048-pad_remove,pad_remove:2048-pad_remove,0:1,0].read().result(),[2, 1, 0])]

for z in tqdm(range(1, unaligned_1x.shape[2])):

    data_box = bounding_box.BoundingBox(start=(0, 0, 0),size=(2048, 2048, 1))

    out_box = bounding_box.BoundingBox(start=(pad_remove, pad_remove, 0),size=(crop_size, crop_size, 1))

    data = np.transpose(unaligned_1x[data_box.start[0]:data_box.end[0],data_box.start[1]:data_box.end[1],z:z+1,0:1].read().result(),[3, 2, 1, 0])

    warped_slice = warp.warp_subvolume(data,data_box,inv_map[:, z:z+1, ...],box1x,stride,
        out_box,
        'lanczos',
        parallelism=1
    )[0, ...]

    warped.append(warped_slice)

warped_xyz = np.transpose(np.concatenate(warped, axis=0), [2, 1, 0])
print(warped_xyz.shape)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# (1948, 1948, 20)

# %% [markdown]
# ## From collab:
# - Render an XZ cross section to check the quality of the alignment visually
#
# ## Notes:
# - This creates the output of the alignment and were the EDX channels could be subsituted.

# %%
# output folder
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
outdir = f"results/{timestamp}_alignment_{patch_size:d}_{stride:d}_{min_peak_ratio:.1f}_{min_peak_sharpness:.1f}"
os.makedirs(outdir, exist_ok=True)

pcc_before_list = []
pcc_after_list = []

for i in range(20):
    fig, ax = plt.subplots(1, 2, figsize=(10, 4))

    # Left: warped_xyz
    ax[0].imshow(warped_xyz[:, :, i], cmap="gray_r")
    coeff_before = pearsonr(
        warped_xyz[:, :, 0].ravel(),
        warped_xyz[:, :, i].ravel()
    )[0]
    ax[0].set_title(f"Chan {i:d} corr with channel 0: {coeff_before:.3f}")
    ax[0].axis("off")

    # Right: unaligned_1x
    ref0 = unaligned_1x[pad_remove:2048-pad_remove,pad_remove:2048-pad_remove, 0, 0].read().result()
    curr = unaligned_1x[pad_remove:2048-pad_remove,pad_remove:2048-pad_remove, i, 0].read().result()
    ax[1].imshow(curr, cmap="gray_r")
    coeff_after = pearsonr(ref0.ravel(), curr.ravel())[0]
    ax[1].set_title(f"Chan {i:d} corr with channel 0: {coeff_after:.3f}")
    ax[1].axis("off")

    pcc_before_list.append(coeff_before)
    pcc_after_list.append(coeff_after)

    # Save figure
    outfile = os.path.join(outdir, f"slice_{i:03d}.png")
    plt.savefig(outfile, dpi=150, bbox_inches="tight")
    plt.close(fig)

print(f"Saved alignment figures to: {outdir}")
print(f"Avg. corrlation to the first channel before and after: {np.mean(pcc_before_list):.3f} and {np.mean(pcc_after_list):.3f}")
# Out:
# Saved alignment figures to: results/20251120_141419_alignment_100_25_1.1_1.1
# Avg. corrlation to the first channel before and after: 0.942 and 0.761

# %% [markdown]
# # Apply the transformation to EDX datacube:
# - First, test on single channel.

# %% [markdown]
# ### First, getting individual frames (this works)

# %%
warnings.filterwarnings("ignore")

# load data
file_path = "../data/EMD/EDXdataset.emd"

# individual frames (one channel) to be stored here
#data_1x_element = np.zeros_like(data_1x).astype('float32')
print(data_1x_element.shape, data_1x_element.dtype)

for k in range(1,data_1x_element.shape[2]+1):
    edx_tmp, _, _ = load_EDX(file_path, first_frame=k-1, last_frame=k, sum_frames=True, haadf_last_frame=False)
    edx_tmp = binning_xyz(edx_tmp[:,:,96:],dim=[2048,2048,250])[:,:,[4,25,28]]
    print(np.sum(edx_tmp))
    data_1x_element[:,:,k-1,0] = edx_tmp.astype('float32')
    print('Frame %d' % k, end='\r')
# Out:
# (2048, 2048, 3, 20, 1) float32
# WARNING | RosettaSciIO | The file contains only one spectrum stream (rsciio.emd._emd_velox:590)
# WARNING:rsciio.emd._emd_velox:The file contains only one spectrum stream
# 102920.75
# WARNING | RosettaSciIO | The file contains only one spectrum stream (rsciio.emd._emd_velox:590)
# WARNING:rsciio.emd._emd_velox:The file contains only one spectrum stream
# 103511.25
# WARNING | RosettaSciIO | The file contains only one spectrum stream (rsciio.emd._emd_velox:590)
# WARNING:rsciio.emd._emd_velox:The file contains only one spectrum stream
# 103845.125
# Frame 3

# %% [markdown]
# ### Summed frames (to check if the above is correct)

# %%
data_1x_element_ref,_,_ = load_EDX(file_path, first_frame=0, last_frame=20, sum_frames=True, haadf_last_frame=False)
data_1x_element_ref= binning_xyz(data_1x_element_ref[:,:,96:],dim=[2048,2048,250])[:,:,24]
print("Are they equal? ", np.array_equal(np.sum(data_1x_element,axis=2).squeeze(),data_1x_element_ref))
# Out:
# WARNING | RosettaSciIO | The file contains only one spectrum stream (rsciio.emd._emd_velox:590)
# WARNING:rsciio.emd._emd_velox:The file contains only one spectrum stream

# %% [markdown]
# #### Display to double-check

# %%
f, ax = plt.subplots(1,2)
ax[0].imshow(data_1x_element_ref,cmap='gray')
ax[1].imshow(np.sum(data_1x_element,axis=2).squeeze(),cmap='gray')

# %% [markdown]
# ### Tensor-store for the unaligned stack of one EDX channel

# %%
unaligned_element = ts.open({
    'driver': 'n5',
    'kvstore': {
         'driver': 'file',
         'path': 'tmp/dataset3/',
     },
     'metadata': {
         'compression': {
             'type': 'gzip'
         },
         'dataType': 'float32',
         'dimensions': data_1x_element.shape,
         'blockSize': [100, 100, 1, 1],
     },
     'create': True,
     'delete_existing': True,}).result()

write_future = unaligned_element.write(data_1x_element)
write_future.result()

# %% [markdown]
# ### Apply the transformation

# %%
pad_remove = patch_size // 2

# Crop region size
crop_size = 2048 - 2*pad_remove

inv_map = map_utils.invert_map(solved, box1x, box1x, stride)

# Initialize warped list with cropped slice 0
warped = [np.transpose(unaligned_element[pad_remove:2048-pad_remove,pad_remove:2048-pad_remove,0:1,0].read().result(),[2, 1, 0])]

for z in tqdm(range(1, unaligned_element.shape[2])):

    data_box = bounding_box.BoundingBox(start=(0, 0, 0),size=(2048, 2048, 1))

    out_box = bounding_box.BoundingBox(start=(pad_remove, pad_remove, 0),size=(crop_size, crop_size, 1))

    data = np.transpose(unaligned_element[data_box.start[0]:data_box.end[0],data_box.start[1]:data_box.end[1],z:z+1,0:1].read().result(),[3, 2, 1, 0])

    warped_slice = warp.warp_subvolume(data,data_box,inv_map[:, z:z+1, ...],box1x,stride,
        out_box,
        'lanczos',
        parallelism=1
    )[0, ...]

    warped.append(warped_slice)

warped_xyz = np.transpose(np.concatenate(warped, axis=0), [2, 1, 0])
print(warped_xyz.shape)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# (1948, 1948, 20)

# %% [markdown]
# ### Save the output

# %%
# output folder
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
outdir = f"results/{timestamp}_alignment_element_{patch_size:d}_{stride:d}_{min_peak_ratio:.1f}_{min_peak_sharpness:.1f}"
os.makedirs(outdir, exist_ok=True)

pcc_before_list = []
pcc_after_list = []

for i in range(20):
    fig, ax = plt.subplots(1, 2, figsize=(10, 4))

    # Left: warped_xyz
    ax[0].imshow(warped_xyz[:, :, i], cmap="gray_r")
    coeff_before = pearsonr(
        warped_xyz[:, :, 0].ravel(),
        warped_xyz[:, :, i].ravel()
    )[0]
    ax[0].set_title(f"Chan {i:d} corr with channel 0: {coeff_before:.3f}")
    ax[0].axis("off")

    # Right: unaligned_1x
    ref0 = unaligned_element[pad_remove:2048-pad_remove,pad_remove:2048-pad_remove, 0, 0].read().result()
    curr = unaligned_element[pad_remove:2048-pad_remove,pad_remove:2048-pad_remove, i, 0].read().result()
    ax[1].imshow(curr, cmap="gray_r")
    coeff_after = pearsonr(ref0.ravel(), curr.ravel())[0]
    ax[1].set_title(f"Chan {i:d} corr with channel 0: {coeff_after:.3f}")
    ax[1].axis("off")

    pcc_before_list.append(coeff_before)
    pcc_after_list.append(coeff_after)

    # Save figure
    outfile = os.path.join(outdir, f"slice_{i:03d}.png")
    plt.savefig(outfile, dpi=150, bbox_inches="tight")
    plt.close(fig)

print(f"Saved alignment figures to: {outdir}")
print(f"Avg. corrlation to the first channel before and after: {np.mean(pcc_before_list):.3f} and {np.mean(pcc_after_list):.3f}")
# Out:
# Saved alignment figures to: results/20251120_205831_alignment_element_100_25_1.1_1.1
# Avg. corrlation to the first channel before and after: 0.066 and 0.061

# %% [markdown]
# ### Comparison

# %%
from skimage.exposure import match_histograms

# Extract the images you want to match
ref = data_1x_element_ref[pad_remove:2048-pad_remove,pad_remove:2048-pad_remove]
src = np.sum(warped_xyz, axis=2).squeeze()

# histogram matching (optional
matched = match_histograms(src, ref, channel_axis=None)
f, ax = plt.subplots(1, 2, figsize=(15,10))

ax[0].set_title("Unaligned sum")
ax[0].imshow(ref[250:500,250:500], cmap='jet')


ax[1].set_title("Aligned sum")
ax[1].imshow(matched[250:500,250:500], cmap='jet')
